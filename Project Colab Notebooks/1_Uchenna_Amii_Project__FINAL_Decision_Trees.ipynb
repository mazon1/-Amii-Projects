# %% [markdown]
# ### Import Libraries & Read in Data

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from sklearn.model_selection import train_test_split
import plotly.graph_objects as go
import seaborn as sns

# import google drive
from google.colab import drive
drive.mount('/content/drive/')

# Change directory to google drive- Just upload the file right into the drive you want(Uchennamachine) for easy access
# %cd /content/drive/My Drive/

df = pd.read_csv("nasa_data.csv")

#define titanic - you'd need this going forward
nasa = pd.read_csv('nasa_data.csv')
nasa.head()
# Out:
# Mounted at /content/drive/
# /content/drive/My Drive
#    unit_number  time_in_cycles  Altitud  ...  condition  max_cycles  target
# 0            1               1  -0.0007  ...          1         192     191
# 1            1               2   0.0019  ...          1         192     190
# 2            1               3  -0.0043  ...          1         192     189
# 3            1               4   0.0007  ...          1         192     188
# 4            1               5  -0.0019  ...          1         192     187
#
# [5 rows x 29 columns]

# %%
#defining a new target variable based on a minimum threshold of 25
target = 25
label_positive =nasa['target'] <= target 
nasa['label_target']=1
nasa.loc[label_positive,'label_target'] = 0

#Unit number not likely to be relevant to the process, also condition is just the data set #
nasa.drop(columns=['max_cycles','target','unit_number','condition'],inplace = True)

# %% [markdown]
# ### Split into train and test set
# Note: Final Test set not included so technically , test set referred to here is the validation set

# %%
X = nasa.drop(['label_target'], axis=1)
y = nasa['label_target']

#splitting the data set (note we already have an actual test set, so this test set here is the validation set)
X_train, X_val, y_train, y_val = train_test_split( X, y, test_size=0.33, random_state=42,stratify=y)

# %%
#confirming that the split was done (67% to 33%)
for dataset in [y_train, y_val]:
    print(round(len(dataset) / len(y), 2))
# Out:
# 0.67
# 0.33

# %%
#Display X_train
X_train.head()
# Out:
#         time_in_cycles  Altitud  Mach Number  ...  PCNfR_dmd    W31      W32
# 159047             299  35.0020       0.8417  ...     100.00  15.15   9.2185
# 32086               64  42.0064       0.8400  ...     100.00  10.65   6.2992
# 155840             196  35.0050       0.8400  ...     100.00  14.98   9.1078
# 134494              98  20.0057       0.7007  ...     100.00  24.61  14.6590
# 126998              25  25.0076       0.6215  ...      84.93  14.33   8.4650
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Write out all data

# %%
X_train.to_csv('nasatrain_features.csv', index=False)
X_val.to_csv('nasaval_features.csv', index=False)


y_train.to_csv('nasatrain_labels.csv', index=False)
y_val.to_csv('nasaval_labels.csv', index=False)

# %%
#Read in Training Data
tr_features = pd.read_csv('nasatrain_features.csv')
tr_labels = pd.read_csv('nasatrain_labels.csv')

# %%
#Define Results to print
def print_results(results):
    print('BEST PARAMS: {}\n'.format(results.best_params_))

    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print('{} (+/-{}) for {}'.format(round(mean, 3), round(std * 2, 3), params))

# %% [markdown]
# # Decision Tree

# %%
#Importing Libraries
import joblib
import pandas as pd
from sklearn import tree
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %%
#Fitting the Model and Evaluating
dtree = tree.DecisionTreeClassifier()
parameters = {
    
    'min_samples_leaf': [1,5,10,15,20],
    # to test 1,5,10,15,20 leaves
    'max_depth': [2,4,8,16,32,None],
    'min_samples_split': [5,10,15,20],
    'criterion': ['gini','entropy'],
    'splitter': ['best','random']
    # to test various depths including No limitiation on the depth i.e. None
    
}
#using GridSearchCV to loop through predefined hyperparameters and fit your estimator (model) on your training set
cv = GridSearchCV(dtree,parameters, cv = 5)
#cv = 5 meaning it will run 5-fold validation for each hyperparameter combination
cv.fit(tr_features,tr_labels.values.ravel())
# we use ravel for the labels to convert it to an array, since the label is usually just one column and the algorithm expects an array
print_results(cv)
# Out:
# BEST PARAMS: {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'best'}
#
# 0.909 (+/-0.003) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# 0.899 (+/-0.016) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'random'}
# 0.909 (+/-0.003) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.89 (+/-0.007) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.909 (+/-0.003) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'best'}
# 0.891 (+/-0.009) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'random'}
# 0.909 (+/-0.003) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'best'}
# 0.889 (+/-0.011) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'random'}
# 0.909 (+/-0.003) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'best'}
# 0.89 (+/-0.012) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'random'}
# 0.909 (+/-0.003) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.89 (+/-0.017) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.909 (+/-0.003) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'best'}
# 0.889 (+/-0.01) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'random'}
# 0.909 (+/-0.003) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'best'}
# 0.899 (+/-0.021) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'random'}
# 0.909 (+/-0.003) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# 0.895 (+/-0.015) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'random'}
# 0.909 (+/-0.003) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'best'}
# 0.894 (+/-0.018) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'random'}
# 0.909 (+/-0.003) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'best'}
# 0.89 (+/-0.012) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'random'}
# 0.909 (+/-0.003) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'best'}
# 0.892 (+/-0.012) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'random'}
# 0.909 (+/-0.003) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'best'}
# 0.886 (+/-0.003) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'random'}
# 0.909 (+/-0.003) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'best'}
# 0.895 (+/-0.011) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'random'}
# 0.909 (+/-0.003) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'best'}
# 0.887 (+/-0.004) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'random'}
# 0.909 (+/-0.003) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'best'}
# 0.889 (+/-0.008) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'random'}
# 0.909 (+/-0.003) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'best'}
# 0.892 (+/-0.011) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'random'}
# 0.909 (+/-0.003) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'best'}
# 0.899 (+/-0.015) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'random'}
# 0.909 (+/-0.003) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'best'}
# 0.893 (+/-0.016) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'random'}
# 0.909 (+/-0.003) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'best'}
# 0.894 (+/-0.012) for {'criterion': 'gini', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'random'}
# 0.932 (+/-0.004) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# 0.9 (+/-0.012) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'random'}
# 0.932 (+/-0.004) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.9 (+/-0.008) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.932 (+/-0.004) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'best'}
# 0.898 (+/-0.016) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'random'}
# 0.932 (+/-0.004) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'best'}
# 0.903 (+/-0.012) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'random'}
# 0.932 (+/-0.004) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'best'}
# 0.91 (+/-0.024) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'random'}
# 0.932 (+/-0.004) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.907 (+/-0.009) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.932 (+/-0.004) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'best'}
# 0.906 (+/-0.02) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'random'}
# 0.932 (+/-0.004) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'best'}
# 0.905 (+/-0.01) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'random'}
# 0.932 (+/-0.004) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# 0.898 (+/-0.023) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'random'}
# 0.932 (+/-0.004) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'best'}
# 0.906 (+/-0.013) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'random'}
# 0.932 (+/-0.004) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'best'}
# 0.903 (+/-0.008) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'random'}
# 0.932 (+/-0.004) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'best'}
# 0.898 (+/-0.018) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'random'}
# 0.932 (+/-0.004) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'best'}
# 0.904 (+/-0.019) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'random'}
# 0.932 (+/-0.004) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'best'}
# 0.904 (+/-0.019) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'random'}
# 0.932 (+/-0.004) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'best'}
# 0.902 (+/-0.016) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'random'}
# 0.932 (+/-0.004) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'best'}
# 0.902 (+/-0.012) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'random'}
# 0.932 (+/-0.004) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'best'}
# 0.909 (+/-0.011) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'random'}
# 0.932 (+/-0.004) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'best'}
# 0.906 (+/-0.011) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'random'}
# 0.932 (+/-0.004) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'best'}
# 0.907 (+/-0.009) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'random'}
# 0.932 (+/-0.004) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'best'}
# 0.909 (+/-0.021) for {'criterion': 'gini', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'random'}
# 0.955 (+/-0.0) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# 0.935 (+/-0.016) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'random'}
# 0.955 (+/-0.0) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.93 (+/-0.028) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.955 (+/-0.0) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'best'}
# 0.935 (+/-0.013) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'random'}
# 0.955 (+/-0.001) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'best'}
# 0.922 (+/-0.007) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'random'}
# 0.955 (+/-0.001) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'best'}
# 0.929 (+/-0.024) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'random'}
# 0.955 (+/-0.001) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.933 (+/-0.025) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.955 (+/-0.0) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'best'}
# 0.933 (+/-0.018) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'random'}
# 0.955 (+/-0.001) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'best'}
# 0.934 (+/-0.016) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'random'}
# 0.955 (+/-0.0) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# 0.93 (+/-0.006) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'random'}
# 0.955 (+/-0.0) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'best'}
# 0.933 (+/-0.016) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'random'}
# 0.955 (+/-0.0) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'best'}
# 0.929 (+/-0.018) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'random'}
# 0.955 (+/-0.0) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'best'}
# 0.934 (+/-0.024) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'random'}
# 0.955 (+/-0.001) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'best'}
# 0.936 (+/-0.027) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'random'}
# 0.955 (+/-0.001) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'best'}
# 0.927 (+/-0.011) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'random'}
# 0.955 (+/-0.001) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'best'}
# 0.936 (+/-0.018) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'random'}
# 0.955 (+/-0.001) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'best'}
# 0.929 (+/-0.029) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'random'}
# 0.955 (+/-0.001) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'best'}
# 0.94 (+/-0.014) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'random'}
# 0.955 (+/-0.001) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'best'}
# 0.933 (+/-0.015) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'random'}
# 0.955 (+/-0.001) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'best'}
# 0.924 (+/-0.006) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'random'}
# 0.955 (+/-0.001) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'best'}
# 0.931 (+/-0.012) for {'criterion': 'gini', 'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'random'}
# 0.955 (+/-0.002) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# 0.955 (+/-0.003) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'random'}
# 0.955 (+/-0.002) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.954 (+/-0.006) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.955 (+/-0.002) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'best'}
# 0.952 (+/-0.012) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'random'}
# 0.956 (+/-0.002) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'best'}
# 0.956 (+/-0.001) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'random'}
# 0.956 (+/-0.002) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'best'}
# 0.955 (+/-0.003) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'random'}
# 0.957 (+/-0.001) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.955 (+/-0.005) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.956 (+/-0.002) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'best'}
# 0.953 (+/-0.003) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'random'}
# 0.957 (+/-0.001) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'best'}
# 0.955 (+/-0.003) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# 0.955 (+/-0.012) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'best'}
# 0.954 (+/-0.008) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'best'}
# 0.957 (+/-0.004) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'random'}
# 0.958 (+/-0.001) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'best'}
# 0.956 (+/-0.005) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'random'}
# 0.958 (+/-0.001) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'best'}
# 0.956 (+/-0.006) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'best'}
# 0.955 (+/-0.002) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'random'}
# 0.958 (+/-0.001) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'best'}
# 0.956 (+/-0.006) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'random'}
# 0.958 (+/-0.001) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'best'}
# 0.956 (+/-0.003) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'random'}
# 0.959 (+/-0.001) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'best'}
# 0.957 (+/-0.004) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'random'}
# 0.959 (+/-0.001) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'best'}
# 0.953 (+/-0.006) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'random'}
# 0.959 (+/-0.001) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'best'}
# 0.952 (+/-0.012) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'random'}
# 0.959 (+/-0.001) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'best'}
# 0.955 (+/-0.005) for {'criterion': 'gini', 'max_depth': 16, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'random'}
# 0.951 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# 0.951 (+/-0.001) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'random'}
# 0.952 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.952 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'best'}
# 0.953 (+/-0.001) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'random'}
# 0.953 (+/-0.003) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'best'}
# 0.954 (+/-0.001) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'random'}
# 0.955 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'best'}
# 0.955 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'random'}
# 0.955 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.954 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.956 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'best'}
# 0.957 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'random'}
# 0.956 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'best'}
# 0.956 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# 0.956 (+/-0.004) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'best'}
# 0.958 (+/-0.004) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'best'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'best'}
# 0.956 (+/-0.005) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'best'}
# 0.957 (+/-0.005) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'best'}
# 0.957 (+/-0.003) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'best'}
# 0.957 (+/-0.003) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'best'}
# 0.957 (+/-0.003) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'random'}
# 0.959 (+/-0.001) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'best'}
# 0.957 (+/-0.003) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'random'}
# 0.959 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'best'}
# 0.955 (+/-0.005) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'random'}
# 0.958 (+/-0.001) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'best'}
# 0.956 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'random'}
# 0.959 (+/-0.001) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'best'}
# 0.957 (+/-0.002) for {'criterion': 'gini', 'max_depth': 32, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'random'}
# 0.951 (+/-0.002) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# 0.949 (+/-0.003) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'random'}
# 0.952 (+/-0.002) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.952 (+/-0.003) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'best'}
# 0.955 (+/-0.003) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'random'}
# 0.953 (+/-0.003) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'best'}
# 0.955 (+/-0.003) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'random'}
# 0.955 (+/-0.002) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'best'}
# 0.956 (+/-0.003) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'random'}
# 0.955 (+/-0.002) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.955 (+/-0.003) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.955 (+/-0.002) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'best'}
# 0.957 (+/-0.002) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'random'}
# 0.956 (+/-0.001) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'best'}
# 0.956 (+/-0.001) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# 0.957 (+/-0.003) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'best'}
# 0.956 (+/-0.003) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'best'}
# 0.957 (+/-0.002) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'best'}
# 0.958 (+/-0.004) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'best'}
# 0.957 (+/-0.003) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'best'}
# 0.957 (+/-0.002) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'best'}
# 0.957 (+/-0.003) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'best'}
# 0.957 (+/-0.005) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'best'}
# 0.957 (+/-0.004) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'best'}
# 0.955 (+/-0.006) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'best'}
# 0.956 (+/-0.003) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'random'}
# 0.958 (+/-0.002) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'best'}
# 0.956 (+/-0.002) for {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'random'}
# 0.91 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# 0.895 (+/-0.017) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'random'}
# 0.91 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.891 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.91 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'best'}
# 0.89 (+/-0.016) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'random'}
# 0.91 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'best'}
# 0.891 (+/-0.011) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'random'}
# 0.91 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'best'}
# 0.893 (+/-0.021) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'random'}
# 0.91 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.889 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.91 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'best'}
# 0.888 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'random'}
# 0.91 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'best'}
# 0.889 (+/-0.008) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'random'}
# 0.91 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# 0.896 (+/-0.018) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'random'}
# 0.91 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'best'}
# 0.887 (+/-0.006) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'random'}
# 0.91 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'best'}
# 0.889 (+/-0.011) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'random'}
# 0.91 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'best'}
# 0.891 (+/-0.013) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'random'}
# 0.91 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'best'}
# 0.896 (+/-0.014) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'random'}
# 0.91 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'best'}
# 0.891 (+/-0.011) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'random'}
# 0.91 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'best'}
# 0.892 (+/-0.016) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'random'}
# 0.91 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'best'}
# 0.893 (+/-0.015) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'random'}
# 0.91 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'best'}
# 0.892 (+/-0.019) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'random'}
# 0.91 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'best'}
# 0.891 (+/-0.013) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'random'}
# 0.91 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'best'}
# 0.893 (+/-0.017) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'random'}
# 0.91 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'best'}
# 0.892 (+/-0.014) for {'criterion': 'entropy', 'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'random'}
# 0.924 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# 0.904 (+/-0.015) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'random'}
# 0.924 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.905 (+/-0.017) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.924 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'best'}
# 0.906 (+/-0.012) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'random'}
# 0.924 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'best'}
# 0.897 (+/-0.016) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'random'}
# 0.924 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'best'}
# 0.901 (+/-0.016) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'random'}
# 0.924 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.903 (+/-0.011) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.924 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'best'}
# 0.905 (+/-0.008) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'random'}
# 0.924 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'best'}
# 0.903 (+/-0.014) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'random'}
# 0.924 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# 0.897 (+/-0.014) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'random'}
# 0.924 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'best'}
# 0.907 (+/-0.014) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'random'}
# 0.924 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'best'}
# 0.9 (+/-0.014) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'random'}
# 0.924 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'best'}
# 0.9 (+/-0.014) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'random'}
# 0.924 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'best'}
# 0.9 (+/-0.012) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'random'}
# 0.924 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'best'}
# 0.901 (+/-0.012) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'random'}
# 0.924 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'best'}
# 0.903 (+/-0.012) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'random'}
# 0.924 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'best'}
# 0.899 (+/-0.008) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'random'}
# 0.924 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'best'}
# 0.901 (+/-0.015) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'random'}
# 0.924 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'best'}
# 0.907 (+/-0.016) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'random'}
# 0.924 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'best'}
# 0.907 (+/-0.027) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'random'}
# 0.924 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'best'}
# 0.9 (+/-0.011) for {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# 0.925 (+/-0.008) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.932 (+/-0.016) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'best'}
# 0.927 (+/-0.006) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'best'}
# 0.933 (+/-0.014) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'best'}
# 0.935 (+/-0.025) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.921 (+/-0.022) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'best'}
# 0.931 (+/-0.015) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'best'}
# 0.934 (+/-0.011) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# 0.933 (+/-0.014) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'best'}
# 0.924 (+/-0.019) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'best'}
# 0.92 (+/-0.017) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'best'}
# 0.926 (+/-0.017) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'best'}
# 0.931 (+/-0.012) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'best'}
# 0.939 (+/-0.013) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'best'}
# 0.925 (+/-0.016) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'best'}
# 0.934 (+/-0.023) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'best'}
# 0.932 (+/-0.016) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'best'}
# 0.933 (+/-0.014) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'best'}
# 0.929 (+/-0.012) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'best'}
# 0.927 (+/-0.016) for {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'random'}
# 0.954 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# 0.953 (+/-0.006) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'random'}
# 0.954 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.954 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.955 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'best'}
# 0.955 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'random'}
# 0.955 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'best'}
# 0.956 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'random'}
# 0.955 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'best'}
# 0.953 (+/-0.008) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'random'}
# 0.955 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.954 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.956 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'best'}
# 0.955 (+/-0.005) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'random'}
# 0.956 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'best'}
# 0.956 (+/-0.005) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'random'}
# 0.957 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# 0.955 (+/-0.007) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'random'}
# 0.957 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'best'}
# 0.956 (+/-0.005) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'random'}
# 0.957 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'best'}
# 0.956 (+/-0.005) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'random'}
# 0.957 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'best'}
# 0.954 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'random'}
# 0.958 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'best'}
# 0.957 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'random'}
# 0.958 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'best'}
# 0.956 (+/-0.005) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'random'}
# 0.959 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'best'}
# 0.955 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'random'}
# 0.959 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'best'}
# 0.956 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'random'}
# 0.959 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'best'}
# 0.955 (+/-0.004) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'random'}
# 0.959 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'best'}
# 0.953 (+/-0.009) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'random'}
# 0.959 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'best'}
# 0.954 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'random'}
# 0.959 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'best'}
# 0.957 (+/-0.004) for {'criterion': 'entropy', 'max_depth': 16, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# 0.951 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.954 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.954 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'best'}
# 0.955 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'random'}
# 0.955 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'best'}
# 0.955 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'random'}
# 0.954 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'best'}
# 0.955 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'random'}
# 0.955 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.954 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.955 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'best'}
# 0.956 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'random'}
# 0.956 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'best'}
# 0.957 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'random'}
# 0.957 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# 0.956 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'random'}
# 0.957 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'best'}
# 0.957 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'random'}
# 0.957 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'best'}
# 0.957 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'random'}
# 0.957 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'best'}
# 0.957 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'random'}
# 0.959 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'best'}
# 0.956 (+/-0.004) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'random'}
# 0.958 (+/-0.004) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'best'}
# 0.958 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'random'}
# 0.959 (+/-0.004) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'best'}
# 0.956 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'random'}
# 0.958 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'best'}
# 0.956 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'random'}
# 0.959 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'best'}
# 0.954 (+/-0.004) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'random'}
# 0.959 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'best'}
# 0.956 (+/-0.004) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'random'}
# 0.959 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'best'}
# 0.956 (+/-0.001) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'random'}
# 0.959 (+/-0.002) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'best'}
# 0.956 (+/-0.003) for {'criterion': 'entropy', 'max_depth': 32, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'random'}
# 0.953 (+/-0.002) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# 0.951 (+/-0.001) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'random'}
# 0.953 (+/-0.001) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'best'}
# 0.952 (+/-0.002) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'splitter': 'random'}
# 0.954 (+/-0.001) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'best'}
# 0.955 (+/-0.002) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 15, 'splitter': 'random'}
# 0.955 (+/-0.002) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'best'}
# 0.956 (+/-0.003) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 20, 'splitter': 'random'}
# 0.954 (+/-0.002) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'best'}
# 0.955 (+/-0.001) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 5, 'splitter': 'random'}
# 0.954 (+/-0.002) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'best'}
# 0.955 (+/-0.004) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'random'}
# 0.955 (+/-0.001) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'best'}
# 0.956 (+/-0.003) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 15, 'splitter': 'random'}
# 0.956 (+/-0.002) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'best'}
# 0.957 (+/-0.003) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 5, 'min_samples_split': 20, 'splitter': 'random'}
# 0.957 (+/-0.002) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'best'}
# 0.957 (+/-0.002) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 5, 'splitter': 'random'}
# 0.957 (+/-0.002) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'best'}
# 0.956 (+/-0.005) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 10, 'splitter': 'random'}
# 0.957 (+/-0.002) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'best'}
# 0.957 (+/-0.003) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 15, 'splitter': 'random'}
# 0.957 (+/-0.002) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'best'}
# 0.957 (+/-0.002) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 10, 'min_samples_split': 20, 'splitter': 'random'}
# 0.959 (+/-0.004) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'best'}
# 0.957 (+/-0.001) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 15, 'min_samples_split': 5, 'splitter': 'random'}
# 0.959 (+/-0.003) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'best'}
# 0.957 (+/-0.003) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 15, 'min_samples_split': 10, 'splitter': 'random'}
# 0.959 (+/-0.003) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'best'}
# 0.957 (+/-0.004) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 15, 'min_samples_split': 15, 'splitter': 'random'}
# 0.958 (+/-0.003) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'best'}
# 0.958 (+/-0.002) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 15, 'min_samples_split': 20, 'splitter': 'random'}
# 0.959 (+/-0.002) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'best'}
# 0.956 (+/-0.001) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 5, 'splitter': 'random'}
# 0.959 (+/-0.002) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'best'}
# 0.956 (+/-0.003) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 10, 'splitter': 'random'}
# 0.959 (+/-0.002) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'best'}
# 0.957 (+/-0.006) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 15, 'splitter': 'random'}
# 0.959 (+/-0.002) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'best'}
# 0.955 (+/-0.004) for {'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 20, 'min_samples_split': 20, 'splitter': 'random'}

# %%
cv.best_estimator_
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=16, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=20, min_samples_split=15,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# # Visualizing the Decision Tree

# %%
#Import Libraries
from sklearn.externals.six import StringIO
from pydotplus import graph_from_dot_data
from IPython.display import Image
from sklearn.tree import export_graphviz

# %%
#Plot Tree
dot_data = StringIO()
export_graphviz(dtree, out_file=dot_data, filled=True, rounded=True, impurity=False, special_characters=True)
graph = graph_from_dot_data(dot_data.getvalue())
dtree = cv.best_estimator_
Image(graph.create_png(), unconfined=False)

# %% [markdown]
# ### Write out pickled model
# We pickle the model by saving it and writing it to a file that can be used to compare with other hyperparameters performance

# %%
joblib.dump(cv.best_estimator_, '../../../NASADT_model.pkl')
# Out:
# ['../../../NASADT_model.pkl']

# %%
cv = cv.best_estimator_
#Predicting the labels using the optimized hyperparameters
tr_labelspredict = cv.predict(tr_features)

# %%
# To view accuracy score, recall score, precision score and f1 score
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

 #Train Scores

acc_train = accuracy_score(y_train,tr_labelspredict)
p_score_train = precision_score(y_train,tr_labelspredict)
r_score_train = recall_score(y_train,tr_labelspredict)
f1_score_train = f1_score(y_train,tr_labelspredict)

 #Test Scores

val_labelspredict = cv.predict(X_val)
acc_test = accuracy_score(y_val,val_labelspredict)
p_score_test = precision_score(y_val,val_labelspredict)
r_score_test = recall_score(y_val,val_labelspredict)
f1_score_test = f1_score(y_val,val_labelspredict)

print(f'The Accuracy score for the training set is:{acc_train}')
print(f'The Precision score for the training set is:{p_score_train}')
print(f'The Recall score for the training set is:{r_score_train}')
print(f'The F1 score for the training set is:{f1_score_train}')
print('--------------------------------------------------------------')
print(f'The Accuracy score for the validation set is:{acc_test}')
print(f'The Precision score for the validation set is:{p_score_test}')
print(f'The Recall score for the validation set is:{r_score_test}')
print(f'The F1 score for the validation set is:{f1_score_test}')
# train_results = [acc_train,p_score_train,r_score_train,f1_score_train]
# test_results = [acc_test,p_score_test,r_score_test,f1_score_test]
# Out:
# The Accuracy score for the training set is:0.9718261355174982
# The Precision score for the training set is:0.9829101972303819
# The Recall score for the training set is:0.9852979839939425
# The F1 score for the training set is:0.9841026422070386
# --------------------------------------------------------------
# The Accuracy score for the validation set is:0.9609025113853248
# The Precision score for the validation set is:0.9766198922556055
# The Recall score for the validation set is:0.9792680843795372
# The F1 score for the validation set is:0.9779421955457948
